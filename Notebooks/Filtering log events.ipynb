# %%
import pandas as pd

# %%
# !kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store \
    -f 2019-Oct.csv -p ../Data\ sets --unzip
# Out:
# 2019-Oct.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
events = pd.read_csv('../Data sets/2019-Oct.csv.zip')

# %%
events.shape
# Out:
# (42448764, 9)

# %%
events.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %% [markdown]
# ##### Выберем категорию только сматрфоны по `category_id`

# %%
events = events.drop(['product_id', 'brand', 'category_code', 'user_session'], axis=1)

# %%
events.head()
# Out:
#                 event_time event_type          category_id    price    user_id
# 0  2019-10-01 00:00:00 UTC       view  2103807459595387724    35.79  541312140
# 1  2019-10-01 00:00:00 UTC       view  2053013552326770905    33.20  554748717
# 2  2019-10-01 00:00:01 UTC       view  2053013559792632471   543.10  519107250
# 3  2019-10-01 00:00:01 UTC       view  2053013558920217191   251.74  550050854
# 4  2019-10-01 00:00:04 UTC       view  2053013555631882655  1081.98  535871217

# %%
smartphone = events[(events['category_id'] == 2053013555631882655) & (events['event_type'] == 'purchase')]

# %%
smartphone.head()
# Out:
#                    event_time event_type          category_id   price  \
# 162   2019-10-01 00:02:14 UTC   purchase  2053013555631882655  130.76
# 308   2019-10-01 00:04:37 UTC   purchase  2053013555631882655  642.69
# 618   2019-10-01 00:10:08 UTC   purchase  2053013555631882655  515.67
# 860   2019-10-01 00:14:14 UTC   purchase  2053013555631882655  463.31
# 1558  2019-10-01 02:19:10 UTC   purchase  2053013555631882655  736.18
#
#         user_id
# 162   543272936
# 308   551377651
# 618   524325294
# 860   555083442
# 1558  515246296

# %%
smartphone.shape
# Out:
# (338018, 5)

# %%
smartphone.to_csv('../Data sets/smartphone_raw.csv', index=False)

# %% [markdown]
# Отобрали из 5,28 GB данных 27 MB нужных нам. Отлично, время двигаться дальше!
